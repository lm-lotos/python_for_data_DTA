# %% [markdown]
# <a href="https://colab.research.google.com/github/lm-lotos/python_for_data_DTA/blob/main/work_with_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python for data

# %%
# import pandas
# from pandas import *
import pandas as pd

# %%
url = "kc_house_data.csv"

df = pd.read_csv(url)

df.head()

# %%
df.info()
